# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/practice_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
a_time=time.strftime("%H:%M:%S")
compare_time=time.strftime("%H%M")
current_time=int(compare_time)
print(f"The current time is {a_time}")
if(current_time>=545 and current_time<700):
  print("good morning! time to start yoyur jp session")
elif(current_time>=1800 and current_time<1900):
  print("Time for one hour leet spi")
elif(current_time>=1900 and current_time<=2000):
  print("Time for one hour of leet code")
elif(current_time>=0000 and current_time<100):
  print("Time for guilt free stry writing")
elif(current_time>=115 and current_time<545):
  print("Sleep time")
else:
  print("Guess you are free")
# Out:
# The current time is 09:37:35
# Guess you are free

# %%
import time
bc_str=time.strftime("%H")
bc = int(bc_str)
print(bc_str)
if(bc>=5 and bc<12):
  print(":good Morning")
elif(bc>=12 and bc<17):
  print("good afrternoon")
else:
  print("good evening")
# Out:
# 08
# :good Morning

# %% [markdown]
# In python , an elif is not a nested function; it is a "sibiling" of the if. They must stay in the same vertical line to work together as single chain.
# If you want to do nesting, you have to put a brand new if underneath a print or another command inside that block.

# %% [markdown]
# Sibling V/S Nested

# %% [markdown]
# 1. Siblings (if/ elif/ else): These check deiffrent times. "if it's 5:00, do A. Elif it's 18:00, do B." Tyhese stay on the same margin.
# 2. Nesting (if inside if): This is a "check inside a check>" If it's the japanese session time, THEN check if I have finished my homework yet."
