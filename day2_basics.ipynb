# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/day2_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''day2 python basics
so today i'd like to deep dive in to coments,
escape sequence, and print statments'''
print("Hello world")
# lets comment this line also
print("Hello, my name is Kirtiman.") #can do it here also
print("End with backslash ")
# Out:
# Hello world
# Hello, my name is Kirtiman.
# End with backslash

# %% [markdown]
# Escape sequences
#
# --- these can be done only inside string if done outside it shows error

# %%
print("Hello, \n what \n would you \n like to do " )
# Out:
# Hello,
#  what
#  would you
#  like to do

# %%
print(
    """--- AZURE SYSTEM REPORT---\nDATE:\t05/01/2025\nSTATUS:\t\"Running\"\nLOCAL \tC:\\azure\\bin\\scripts\n"""
    'NOTES:\t\"System is healthy\"\n----------------------------'
)
# Out:
# --- AZURE SYSTEM REPORT---
# DATE:	05/01/2025
# STATUS:	"Operational"
# LOCAL 	C:\azure\bin\scripts
# NOTES:	"System is healthy"
# ----------------------------

# %% [markdown]
# Line Continuation 3 types

# %%
print(""" So i got to know that,
if u put 3 Single or 3 Double quotes.
the code continues in diff line along with no error.
this is called Multi-String literal""")
# Out:
#  So i got to know that,
# if u put 3 Single or 3 Double quotes.
# the code continues in diff line along with no error.
# this is called Multi-String literal

# %%
print("This one is called Explict line conjuction \
cause if we use the backslash it dosent make a new line in the output. \
but it's rather helpful for to keep the clean code in the coding area.")
# Out:
# This one is called Explict line conjuction cause if we use the backslash it dosent make a new line in the output. but it's rather helpful for to keep the clean code in the coding area.

# %%
print(
    'So this one is called impllict cause'
   'computer sees the open bracket.its an easy and clean way to work with.'
    'its same as explict wont make newlines in the output for our convinent. use this \n for new line'
    'but the thing for this is that \n u need to put quotes in each line or it throws \n error'
)
# Out:
# So this one is called impllict causecomputer sees the open bracket.its an easy and clean way to work with.its same as explict wont make newlines in the output for our convinent. use this
#  for new linebut the thing for this is that
#  u need to put quotes in each line or it throws
#  error
