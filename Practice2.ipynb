# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/Practice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user_role=input("Enter yiour status:\t")
import time
current_hour=int(time.strftime("%H"))
match user_role:
  case "Admin":
    print("full access")
  case "User":
    if (current_hour<18):
      print("Limited access")
    else:
      print("access denied for today :(")
  case _:
    print("Maybe try it again")
# Out:
# Enter yiour status:	Admin
# full access

# %%
ip=input("Is the server online? \n Yes | No:\t")
sp=input("Is the database connected? \n Yes | No:\t")
if (ip and sp == "Yes"):
  print("System Healthy :)")
else:
  print("System faliure :(")
# Out:
# Is the server online?
#  Yes | No:	NO
# Is the database connected?
#  Yes | No:	Yes
# System Healthy :)
