# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruit="Mango"
len1=len(fruit)
print(len1)
# Out:
# 5

# %%
pie="Applepie"
print(pie[:5])
print(pie[6])
print(pie[5:])
print(pie[2:6])
print(pie[-8:])
print(pie[:])
# Out:
# Apple
# i
# pie
# plep
# Applepie
# Applepie

# %%
a="Kirtiman"
print(len(a))
print(a[:8])
print(a[-1:])
print(a[-5:])
print(a[1:])
print(a[:])
# Out:
# 8
# Kirtiman
# n
# timan
# irtiman
# Kirtiman
