# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/day15_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# function in pyth (user defined)

# %%
def function_name(parameters): #Syntax
  pass

# %%
def check_server_status(status_string):
  #the if statement checks the input (the beans)
  if status_string == "active":
    return True
  else:
    return False
#this is how u call that function to use it;
result=check_server_status(input("What's the status: "))
print(result)#This will print true
# Out:
# What's the status: disabled
# False
