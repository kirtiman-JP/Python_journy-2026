# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/day1_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World", 34)
# Out:
# Hello World 34

# %% [markdown]
# yp

# %%
a = 20
b = 30
c = a - b
print("sum =", c)
# Out:
# sum = -10

# %%
# #import pandas as pd
# mylist = [ 455, 42, 43,]
# Out:
# ' res = pd.Series(mylist)\nprint("series = \n", res) '

# %%
print("100 \"100\" ")
# Out:
# 100 "100"

# %%
print("hey", 6,7, sep="~",  end="\nok bye")
# Out:
# hey~6~7
# ok bye

# %%
print("Hey i am a good boy\n and the one viweing also an good boy or girl")
# Out:
# Hey i am a good boy
#  and the one viweing alo an good boy or girl
