# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/day16_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **FUNCTION ARRANGEMENTS**
#
# 4.TYPES

# %% [markdown]
# **Required Arguments**

# %%
#THESE ARE THE "MUST_HAVES" THE FUNCTION CANNOT RUN WITHOUT THEM
#eg. to turn on a smart light but need to specify wich room
def turn_on_light(room):#argument is a box for input data. O r simple words its an temporary variable.
  if room == "kitchen":
   print(f"Lighting up the\t{room}!")
  elif room == "washroom":
    print(f"Lighting up the\t{room}")
  else:
    print("Try input again")


turn_on_light("washroom")
turn_on_light("kitchen")
# Out:
# Lighting up the	washroom
# Lighting up the	kitchen!
