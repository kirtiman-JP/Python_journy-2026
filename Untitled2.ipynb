# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **upper():**

# %%
str1="KirTImaN"
print(str1.upper())
# Out:
# KIRTIMAN

# %% [markdown]
# **lower():**

# %%
print(str1.lower())
# Out:
# kirtiman

# %% [markdown]
# **strip():**

# %%
str2=" Silver Spoon"
print(str2.strip())
# Out:
# Silver Spoon

# %% [markdown]
# **rstrip():**

# %%
str3="!!!Hello!!!"
print(str3.rstrip("!"))
# Out:
# !!!Hello

# %% [markdown]
# **replace():**

# %%
print(str2.replace("Sp", "M"))
# Out:
#  Silver Moon

# %% [markdown]
# **split():**

# %%
print(str2.split(" "))
# Out:
# ['', 'Silver', 'Spoon']

# %% [markdown]
# **Capitalize():**

# %%
str4="hello"
# capstr1=str4.capitalize()
print(str4.capitalize())
# print(capstr1)
str5="hello World"
print(str5.capitalize())
# Out:
# Hello
# Hello world
