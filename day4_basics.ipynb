# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/day4_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TypeCasting**

# %% [markdown]
# **Explict Type casting**

# %%
string = "15"
number = 7
string_number = int(string)
sum = number + string_number
print("The sum of both number is: ", sum)
# Out:
# The sum of both number is:  22

# %% [markdown]
# **Implict Type casting**

# %%
a=7
print("The type value of a is:",type(a))
b=3.0
print("The type value of b is:",type(b))
c=a+b
print("The type value of c is:", type(c))
print(c)
# Out:
# The type value of a is: <class 'int'>
# The type value of b is: <class 'float'>
# The type value of c is: <class 'float'>
# 10.0
