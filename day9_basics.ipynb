# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/day9_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **if else conditional statements in python**

# %% [markdown]
# **covered topics are:**
# (if)
# .(if-else)
# .(if-elif-else)
# .(nested if-else-elif)

# %%
appleprice=input("plese enter the market value of  1 kg apple? ")
budget=(input("what's your budget?: "))
if(appleprice<budget):
  print("You can add apples")
else:
  print("You can't add apples")
# Out:
# plese enter the market alue of  1 kg apple? 89
# what's your budget?: 88
# You can't add apples

# %%
#i had encounterd an error here cause i enterd if age > or < so when i enterd age input as 18 its error so addd =
#and u cant do if (a>=18 cause , '>=' not supported between instances of "str" and "int" )
a=input("plz enter your age:")
if(int(a)>=18):
  print("you can drive :)")
else:
  print("you can't drive :(")
# Out:
# plz enter your age:18
# you can drive :)

# %%
num=float(input("enter the value of the number" ))
if (num<0):
  print("Number is negetive.")
elif(num==0):
  print("Number is zero.")
else:
  print("number is positive.")
# Out:
# enter the value of the number-99.3
# Number is negetive.

# %%
#in simple words if elif and slse are like this that or.

num=float(input("Enter your number:"))
if(num<0):
  print("number is -ve.")
elif(num>0):
  if(num<=10):
    print("number is between 1-10")
  elif(num>10 and num<=20):
    print("number is between 11-20")
  else:
    print("number is greater then 20")
else:
  print("number is zero")
# Out:
# Enter your number:45
# number is greater then 20

# %% [markdown]
# exercises

# %%
age=float(input("Enter your age: "))
if (age>=18):
  print("you can enter :)")
else:
  print("too young :(")
# Out:
# Enter your age: 14
# too young :(

# %%
#to compare with sting when taken output use eg weather=="a"

weather=input("what kind of weather is it out there?\n a.Sunny b.Rainy c.not sure?\t")
if (weather=="a"):
  print("wear sunglasses.")
elif (weather=="b"):
  print("take an umbrella")
else:
  print("Check the forecast again")
# Out:
# what kind of weather is it out there?
#  a.Sunny b.Rainy c.not sure?	a
# wear sunglasses.

# %%
#used user_input==secret_password to compare
secret_password="Python123"
user_input=input("Please enter your pasword:\t")
if(user_input==secret_password):
  print("Access Granted!")
else:
  print("Wrong password")
# Out:
# Please enter your pasword:	Python123
# Access Granted!
