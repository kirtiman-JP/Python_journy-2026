# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
appleprice=210
budget=200
if (appleprice<=budget):
  print ("Add apples to cart ")
else:
    print ("No Appels for today")
# Out:
# No Appels for today
