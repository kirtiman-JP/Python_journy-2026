# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **loops**

# %%
# Define a list of numbers
numbers = [1, 2, 3, 4, 5]

# Use a for loop to iterate through the list
print("Iterating through the list:")
for number in numbers:
    print(number)

    # Another example: looping through a range of numbers
    print("\nIterating through a range from 0 to 4:")
    for i in range(5):
        print(i)
