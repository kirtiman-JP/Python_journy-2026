# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtiman-JP/Python_journy-2026/blob/main/day3_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Variables and Types**

# %%
a=1
b=True
c="Kirti"
d=None
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'str'>
# <class 'NoneType'>

# %% [markdown]
# **List**

# %%
list1=[8,5.6,67, [-4,5], ["Sparrow", "Apple"]]
print(list1)
# Out:
# [8, 5.6, 67, [-4, 5], ['Sparrow', 'Apple']]

# %% [markdown]
# **Tuple**

# %%
tuple2=(4,5,6, ("hello world", "ohio gozaimasu"))
print(tuple2)
# Out:
# (4, 5, 6, ('hello world', 'ohio gozaimasu'))

# %% [markdown]
# **Dict**

# %%
dict2={"Name":"sakshi", "class":"5th Grade", "age": 20, "Gender Female?":True}
print(dict2)
# Out:
# {'Name': 'sakshi', 'class': '5th Grade', 'age': 20, 'Gender Female?': True}
